# %%
import numpy as np
from os.path import basename
from glob import glob
from sklearn.svm import SVC
from micromlgen import port
from sklearn.model_selection import train_test_split

def load_features(folder):
    dataset = None
    classmap = {}
    for class_idx, filename in enumerate(glob('%s/*.csv' % folder)):
        class_name = basename(filename)[:-4]
        classmap[class_idx] = class_name
        samples = np.loadtxt(filename, dtype=float, delimiter=',')
        labels = np.ones((len(samples), 1)) * class_idx
        samples = np.hstack((samples, labels))
        dataset = samples if dataset is None else np.vstack((dataset, samples))
    return dataset, classmap

np.random.seed(0)
dataset, classmap = load_features('data2')
X, y = dataset[:, :-1], dataset[:, -1]
# this line is for testing your accuracy only: once you're satisfied with the results, set test_size to 1
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

clf = SVC(kernel='poly', degree=2, gamma=0.1, C=100)
clf.fit(X_train, y_train)

print('Accuracy', clf.score(X_test, y_test))
print('Exported classifier to plain C')
print(port(clf, classmap=classmap))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12584/2235937996.py in <module>
#      20 np.random.seed(0)
#      21 dataset, classmap = load_features('data2')
# ---> 22 X, y = dataset[:, :-1], dataset[:, -1]
#      23 # this line is for testing your accuracy only: once you're satisfied with the results, set test_size to 1
#      24 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
from sklearn.ensemble import RandomForestClassifier
from micromlgen import port
import numpy as np
from glob import glob
from os.path import basename
from sklearn.ensemble import RandomForestClassifier

def load_features(folder):
    dataset = None
    classmap = {}
    for class_idx, filename in enumerate(glob('%s/*.csv' % folder)):
        class_name = basename(filename)[:-4]
        classmap[class_idx] = class_name
        samples = np.loadtxt(filename, dtype=float, delimiter=',')
        labels = np.ones((len(samples), 1)) * class_idx
        samples = np.hstack((samples, labels))
        dataset = samples if dataset is None else np.vstack((dataset, samples))

    return dataset, classmap

np.random.seed(0)
dataset, classmap = load_features('data')
X, y = dataset[:, :-1], dataset[:, -1]

classifier = RandomForestClassifier(n_estimators=30, max_depth=10).fit(X, y)
c_code = port(classifier, classmap=classmap)
print(c_code)
# Out:
# #pragma once
# #include <cstdarg>
# namespace Eloquent {
#     namespace ML {
#         namespace Port {
#             class RandomForest {
#                 public:
#                     /**
#                     * Predict class for features vector
#                     */
#                     int predict(float *x) {
#                         uint8_t votes[4] = { 0 };
#                         // tree #1
#                         if (x[4] <= 2.005000114440918) {
#                             if (x[2] <= 1.0550003051757812) {
#                                 if (x[5] <= 2.6700000762939453) {
#                                     if (x[0] <= 0.7199997901916504) {
#                                         if (x[1] <= 0.804999828338623) {
#                                             if (x[6] <= 3.4200000762939453) {
#                                                 if (x[7] <= 4.229999542236328) {
#                                                     if (x[10] <= 6.68499755859375) {
#                                                         if (x[28] <= 1.4600000381469727) {
#                                                             votes[0] += 1;
#                                                         }
#
#                                                         else {
#                                                             votes[2] += 1;
#                                                         }
#                                                     }
#
#                                                     else {
#                                                         votes[3] += 1;
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     votes[3] += 1;
#                                                 }
#                                             }
#
#                                             else {
#                                                 votes[3] += 1;
#                                             }
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[30] <= 0.804999828338623) {
#                                             if (x[13] <= 6.595001220703125) {
#                                                 if (x[1] <= 0.804999828338623) {
#                                                     if (x[6] <= 3.4200000762939453) {
#                                                         if (x[8] <= 5.069999694824219) {
#                                                             if (x[21] <= 6.68499755859375) {
#                                                                 votes[3] += 1;
#                                                             }
#
#                                                             else {
#                                                                 votes[2] += 1;
#                                                             }
#                                                         }
#
#                                                         else {
#                                                             votes[0] += 1;
#                                                         }
#                                                     }
#
#                                                     else {
#                                                         votes[0] += 1;
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     votes[0] += 1;
#                                                 }
#                                             }
#
#                                             else {
#                                                 if (x[21] <= 6.68499755859375) {
#                                                     if (x[13] <= 117.7750015258789) {
#                                                         votes[3] += 1;
#                                                     }
#
#                                                     else {
#                                                         votes[1] += 1;
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     votes[3] += 1;
#                                                 }
#                                             }
#                                         }
#
#                                         else {
#                                             if (x[27] <= 2.005000114440918) {
#                                                 votes[3] += 1;
#                                             }
#
#                                             else {
#                                                 votes[0] += 1;
#                                             }
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[19] <= 8.005001068115234) {
#                                         if (x[18] <= 8.480003356933594) {
#                                             votes[1] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         votes[0] += 1;
#                                     }
#                                 }
#                             }
#
#                             else {
#                                 if (x[23] <= 5.069999694824219) {
#                                     if (x[14] <= 8.810001373291016) {
#                                         if (x[20] <= 7.394996643066406) {
#                                             if (x[1] <= 0.804999828338623) {
#                                                 if (x[21] <= 6.68499755859375) {
#                                                     if (x[30] <= 0.804999828338623) {
#                                                         votes[0] += 1;
#                                                     }
#
#                                                     else {
#                                                         votes[1] += 1;
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     votes[1] += 1;
#                                                 }
#                                             }
#
#                                             else {
#                                                 votes[1] += 1;
#                                             }
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[16] <= 8.979999542236328) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[2] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[19] <= 8.005001068115234) {
#                                         if (x[3] <= 1.4600000381469727) {
#                                             votes[3] += 1;
#                                         }
#
#                                         else {
#                                             votes[1] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         votes[2] += 1;
#                                     }
#                                 }
#                             }
#                         }
#
#                         else {
#                             if (x[17] <= 8.810001373291016) {
#                                 if (x[8] <= 5.069999694824219) {
#                                     if (x[0] <= 0.7199997901916504) {
#                                         votes[2] += 1;
#                                     }
#
#                                     else {
#                                         if (x[29] <= 1.0550003051757812) {
#                                             if (x[26] <= 2.6700000762939453) {
#                                                 votes[1] += 1;
#                                             }
#
#                                             else {
#                                                 votes[2] += 1;
#                                             }
#                                         }
#
#                                         else {
#                                             votes[2] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[9] <= 5.895000457763672) {
#                                         if (x[22] <= 5.895000457763672) {
#                                             votes[1] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         votes[0] += 1;
#                                     }
#                                 }
#                             }
#
#                             else {
#                                 votes[2] += 1;
#                             }
#                         }
#
#                         // tree #2
#                         if (x[27] <= 2.005000114440918) {
#                             if (x[7] <= 4.229999542236328) {
#                                 if (x[17] <= 8.810001373291016) {
#                                     if (x[5] <= 2.6700000762939453) {
#                                         if (x[9] <= 5.895000457763672) {
#                                             if (x[22] <= 5.895000457763672) {
#                                                 if (x[28] <= 1.4600000381469727) {
#                                                     if (x[30] <= 0.804999828338623) {
#                                                         if (x[25] <= 3.4200000762939453) {
#                                                             if (x[0] <= 0.7199997901916504) {
#                                                                 votes[0] += 1;
#                                                             }
#
#                                                             else {
#                                                                 votes[0] += 1;
#                                                             }
#                                                         }
#
#                                                         else {
#                                                             votes[3] += 1;
#                                                         }
#                                                     }
#
#                                                     else {
#                                                         if (x[3] <= 1.4600000381469727) {
#                                                             votes[3] += 1;
#                                                         }
#
#                                                         else {
#                                                             votes[2] += 1;
#                                                         }
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     if (x[20] <= 7.394996643066406) {
#                                                         if (x[0] <= 0.7199997901916504) {
#                                                             votes[2] += 1;
#                                                         }
#
#                                                         else {
#                                                             votes[3] += 1;
#                                                         }
#                                                     }
#
#                                                     else {
#                                                         votes[2] += 1;
#                                                     }
#                                                 }
#                                             }
#
#                                             else {
#                                                 votes[1] += 1;
#                                             }
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[30] <= 0.804999828338623) {
#                                             if (x[28] <= 1.4600000381469727) {
#                                                 if (x[15] <= 8.979999542236328) {
#                                                     votes[1] += 1;
#                                                 }
#
#                                                 else {
#                                                     if (x[10] <= 6.68499755859375) {
#                                                         votes[0] += 1;
#                                                     }
#
#                                                     else {
#                                                         votes[1] += 1;
#                                                     }
#                                                 }
#                                             }
#
#                                             else {
#                                                 votes[3] += 1;
#                                             }
#                                         }
#
#                                         else {
#                                             votes[1] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[0] <= 0.7199997901916504) {
#                                         if (x[8] <= 5.069999694824219) {
#                                             votes[3] += 1;
#                                         }
#
#                                         else {
#                                             votes[1] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         votes[2] += 1;
#                                     }
#                                 }
#                             }
#
#                             else {
#                                 if (x[6] <= 3.4200000762939453) {
#                                     if (x[8] <= 5.069999694824219) {
#                                         votes[3] += 1;
#                                     }
#
#                                     else {
#                                         if (x[20] <= 7.394996643066406) {
#                                             if (x[2] <= 1.0550003051757812) {
#                                                 votes[0] += 1;
#                                             }
#
#                                             else {
#                                                 votes[1] += 1;
#                                             }
#                                         }
#
#                                         else {
#                                             if (x[19] <= 8.005001068115234) {
#                                                 votes[3] += 1;
#                                             }
#
#                                             else {
#                                                 votes[0] += 1;
#                                             }
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[15] <= 8.979999542236328) {
#                                         if (x[16] <= 8.979999542236328) {
#                                             if (x[18] <= 8.480003356933594) {
#                                                 if (x[8] <= 5.069999694824219) {
#                                                     if (x[12] <= 8.005001068115234) {
#                                                         votes[0] += 1;
#                                                     }
#
#                                                     else {
#                                                         votes[1] += 1;
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     votes[1] += 1;
#                                                 }
#                                             }
#
#                                             else {
#                                                 votes[3] += 1;
#                                             }
#                                         }
#
#                                         else {
#                                             votes[2] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         votes[3] += 1;
#                                     }
#                                 }
#                             }
#                         }
#
#                         else {
#                             if (x[7] <= 4.229999542236328) {
#                                 if (x[1] <= 0.804999828338623) {
#                                     if (x[30] <= 0.804999828338623) {
#                                         votes[3] += 1;
#                                     }
#
#                                     else {
#                                         votes[0] += 1;
#                                     }
#                                 }
#
#                                 else {
#                                     votes[1] += 1;
#                                 }
#                             }
#
#                             else {
#                                 if (x[15] <= 8.979999542236328) {
#                                     if (x[26] <= 2.6700000762939453) {
#                                         votes[2] += 1;
#                                     }
#
#                                     else {
#                                         votes[0] += 1;
#                                     }
#                                 }
#
#                                 else {
#                                     votes[2] += 1;
#                                 }
#                             }
#                         }
#
#                         // tree #3
#                         if (x[21] <= 6.68499755859375) {
#                             if (x[1] <= 0.804999828338623) {
#                                 if (x[23] <= 5.069999694824219) {
#                                     if (x[8] <= 5.069999694824219) {
#                                         if (x[28] <= 1.4600000381469727) {
#                                             if (x[27] <= 2.005000114440918) {
#                                                 if (x[14] <= 8.810001373291016) {
#                                                     if (x[4] <= 2.005000114440918) {
#                                                         if (x[2] <= 1.0550003051757812) {
#                                                             if (x[12] <= 8.005001068115234) {
#                                                                 votes[0] += 1;
#                                                             }
#
#                                                             else {
#                                                                 votes[1] += 1;
#                                                             }
#                                                         }
#
#                                                         else {
#                                                             votes[0] += 1;
#                                                         }
#                                                     }
#
#                                                     else {
#                                                         votes[1] += 1;
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     votes[3] += 1;
#                                                 }
#                                             }
#
#                                             else {
#                                                 votes[3] += 1;
#                                             }
#                                         }
#
#                                         else {
#                                             if (x[5] <= 2.6700000762939453) {
#                                                 if (x[3] <= 1.4600000381469727) {
#                                                     votes[3] += 1;
#                                                 }
#
#                                                 else {
#                                                     votes[2] += 1;
#                                                 }
#                                             }
#
#                                             else {
#                                                 votes[3] += 1;
#                                             }
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[14] <= 8.810001373291016) {
#                                             if (x[13] <= 8.480003356933594) {
#                                                 votes[0] += 1;
#                                             }
#
#                                             else {
#                                                 votes[3] += 1;
#                                             }
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     votes[2] += 1;
#                                 }
#                             }
#
#                             else {
#                                 if (x[4] <= 2.005000114440918) {
#                                     if (x[20] <= 7.394996643066406) {
#                                         if (x[8] <= 5.069999694824219) {
#                                             if (x[7] <= 4.229999542236328) {
#                                                 if (x[9] <= -71.0999984741211) {
#                                                     if (x[25] <= 3.4200000762939453) {
#                                                         votes[0] += 1;
#                                                     }
#
#                                                     else {
#                                                         votes[1] += 1;
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     votes[1] += 1;
#                                                 }
#                                             }
#
#                                             else {
#                                                 votes[1] += 1;
#                                             }
#                                         }
#
#                                         else {
#                                             if (x[12] <= 8.005001068115234) {
#                                                 votes[1] += 1;
#                                             }
#
#                                             else {
#                                                 votes[0] += 1;
#                                             }
#                                         }
#                                     }
#
#                                     else {
#                                         votes[3] += 1;
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[2] <= -12.605000019073486) {
#                                         if (x[7] <= 4.229999542236328) {
#                                             votes[2] += 1;
#                                         }
#
#                                         else {
#                                             if (x[29] <= 1.0550003051757812) {
#                                                 votes[2] += 1;
#                                             }
#
#                                             else {
#                                                 if (x[12] <= 8.005001068115234) {
#                                                     votes[0] += 1;
#                                                 }
#
#                                                 else {
#                                                     votes[2] += 1;
#                                                 }
#                                             }
#                                         }
#                                     }
#
#                                     else {
#                                         votes[1] += 1;
#                                     }
#                                 }
#                             }
#                         }
#
#                         else {
#                             if (x[11] <= 7.394996643066406) {
#                                 if (x[23] <= 5.069999694824219) {
#                                     if (x[28] <= 1.4600000381469727) {
#                                         if (x[1] <= 0.804999828338623) {
#                                             votes[2] += 1;
#                                         }
#
#                                         else {
#                                             if (x[5] <= 2.6700000762939453) {
#                                                 votes[1] += 1;
#                                             }
#
#                                             else {
#                                                 votes[2] += 1;
#                                             }
#                                         }
#                                     }
#
#                                     else {
#                                         votes[3] += 1;
#                                     }
#                                 }
#
#                                 else {
#                                     votes[2] += 1;
#                                 }
#                             }
#
#                             else {
#                                 if (x[24] <= 4.229999542236328) {
#                                     votes[0] += 1;
#                                 }
#
#                                 else {
#                                     votes[2] += 1;
#                                 }
#                             }
#                         }
#
#                         // tree #4
#                         if (x[2] <= -12.605000019073486) {
#                             if (x[5] <= 2.6700000762939453) {
#                                 if (x[19] <= 8.005001068115234) {
#                                     if (x[8] <= 5.069999694824219) {
#                                         if (x[3] <= 1.4600000381469727) {
#                                             if (x[1] <= 0.804999828338623) {
#                                                 if (x[22] <= 5.895000457763672) {
#                                                     if (x[28] <= 1.4600000381469727) {
#                                                         if (x[29] <= 1.0550003051757812) {
#                                                             if (x[0] <= 0.7199997901916504) {
#                                                                 votes[3] += 1;
#                                                             }
#
#                                                             else {
#                                                                 votes[0] += 1;
#                                                             }
#                                                         }
#
#                                                         else {
#                                                             votes[3] += 1;
#                                                         }
#                                                     }
#
#                                                     else {
#                                                         votes[3] += 1;
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     votes[3] += 1;
#                                                 }
#                                             }
#
#                                             else {
#                                                 votes[0] += 1;
#                                             }
#                                         }
#
#                                         else {
#                                             if (x[30] <= 0.804999828338623) {
#                                                 votes[3] += 1;
#                                             }
#
#                                             else {
#                                                 votes[2] += 1;
#                                             }
#                                         }
#                                     }
#
#                                     else {
#                                         votes[0] += 1;
#                                     }
#                                 }
#
#                                 else {
#                                     votes[2] += 1;
#                                 }
#                             }
#
#                             else {
#                                 if (x[19] <= 8.005001068115234) {
#                                     if (x[26] <= 2.6700000762939453) {
#                                         if (x[23] <= 5.069999694824219) {
#                                             if (x[17] <= 8.810001373291016) {
#                                                 votes[1] += 1;
#                                             }
#
#                                             else {
#                                                 votes[2] += 1;
#                                             }
#                                         }
#
#                                         else {
#                                             votes[2] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         votes[2] += 1;
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[28] <= 1.4600000381469727) {
#                                         votes[2] += 1;
#                                     }
#
#                                     else {
#                                         votes[3] += 1;
#                                     }
#                                 }
#                             }
#                         }
#
#                         else {
#                             if (x[0] <= 0.7199997901916504) {
#                                 if (x[10] <= 6.68499755859375) {
#                                     if (x[14] <= 8.810001373291016) {
#                                         votes[1] += 1;
#                                     }
#
#                                     else {
#                                         votes[0] += 1;
#                                     }
#                                 }
#
#                                 else {
#                                     votes[1] += 1;
#                                 }
#                             }
#
#                             else {
#                                 if (x[29] <= 1.0550003051757812) {
#                                     if (x[16] <= 8.979999542236328) {
#                                         if (x[13] <= 8.480003356933594) {
#                                             if (x[15] <= 8.979999542236328) {
#                                                 if (x[1] <= 0.804999828338623) {
#                                                     if (x[4] <= 2.005000114440918) {
#                                                         votes[0] += 1;
#                                                     }
#
#                                                     else {
#                                                         votes[1] += 1;
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     if (x[9] <= 5.895000457763672) {
#                                                         votes[1] += 1;
#                                                     }
#
#                                                     else {
#                                                         if (x[20] <= 7.394996643066406) {
#                                                             votes[0] += 1;
#                                                         }
#
#                                                         else {
#                                                             votes[1] += 1;
#                                                         }
#                                                     }
#                                                 }
#                                             }
#
#                                             else {
#                                                 votes[3] += 1;
#                                             }
#                                         }
#
#                                         else {
#                                             if (x[9] <= 5.895000457763672) {
#                                                 votes[1] += 1;
#                                             }
#
#                                             else {
#                                                 votes[3] += 1;
#                                             }
#                                         }
#                                     }
#
#                                     else {
#                                         votes[2] += 1;
#                                     }
#                                 }
#
#                                 else {
#                                     votes[3] += 1;
#                                 }
#                             }
#                         }
#
#                         // tree #5
#                         if (x[0] <= 0.7199997901916504) {
#                             if (x[6] <= 3.4200000762939453) {
#                                 if (x[26] <= 2.6700000762939453) {
#                                     if (x[30] <= 0.804999828338623) {
#                                         if (x[25] <= 3.4200000762939453) {
#                                             if (x[14] <= 8.810001373291016) {
#                                                 if (x[2] <= 1.0550003051757812) {
#                                                     if (x[1] <= 0.804999828338623) {
#                                                         if (x[7] <= 4.229999542236328) {
#                                                             votes[0] += 1;
#                                                         }
#
#                                                         else {
#                                                             votes[3] += 1;
#                                                         }
#                                                     }
#
#                                                     else {
#                                                         votes[0] += 1;
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     votes[0] += 1;
#                                                 }
#                                             }
#
#                                             else {
#                                                 votes[1] += 1;
#                                             }
#                                         }
#
#                                         else {
#                                             if (x[15] <= 8.979999542236328) {
#                                                 votes[3] += 1;
#                                             }
#
#                                             else {
#                                                 votes[0] += 1;
#                                             }
#                                         }
#                                     }
#
#                                     else {
#                                         votes[2] += 1;
#                                     }
#                                 }
#
#                                 else {
#                                     votes[1] += 1;
#                                 }
#                             }
#
#                             else {
#                                 if (x[28] <= 1.4600000381469727) {
#                                     if (x[29] <= 1.0550003051757812) {
#                                         votes[2] += 1;
#                                     }
#
#                                     else {
#                                         if (x[1] <= 0.804999828338623) {
#                                             if (x[30] <= 0.804999828338623) {
#                                                 votes[3] += 1;
#                                             }
#
#                                             else {
#                                                 votes[1] += 1;
#                                             }
#                                         }
#
#                                         else {
#                                             votes[1] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     votes[3] += 1;
#                                 }
#                             }
#                         }
#
#                         else {
#                             if (x[13] <= 6.595001220703125) {
#                                 if (x[21] <= 6.68499755859375) {
#                                     if (x[19] <= 8.005001068115234) {
#                                         if (x[30] <= 0.804999828338623) {
#                                             if (x[15] <= 8.979999542236328) {
#                                                 if (x[25] <= 3.4200000762939453) {
#                                                     if (x[11] <= 7.394996643066406) {
#                                                         if (x[3] <= 1.4600000381469727) {
#                                                             if (x[9] <= 5.895000457763672) {
#                                                                 votes[0] += 1;
#                                                             }
#
#                                                             else {
#                                                                 votes[1] += 1;
#                                                             }
#                                                         }
#
#                                                         else {
#                                                             if (x[12] <= 8.005001068115234) {
#                                                                 votes[0] += 1;
#                                                             }
#
#                                                             else {
#                                                                 votes[1] += 1;
#                                                             }
#                                                         }
#                                                     }
#
#                                                     else {
#                                                         votes[1] += 1;
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     votes[3] += 1;
#                                                 }
#                                             }
#
#                                             else {
#                                                 votes[3] += 1;
#                                             }
#                                         }
#
#                                         else {
#                                             if (x[10] <= 6.68499755859375) {
#                                                 if (x[27] <= 2.005000114440918) {
#                                                     if (x[3] <= 1.4600000381469727) {
#                                                         votes[3] += 1;
#                                                     }
#
#                                                     else {
#                                                         if (x[1] <= 0.804999828338623) {
#                                                             votes[2] += 1;
#                                                         }
#
#                                                         else {
#                                                             votes[3] += 1;
#                                                         }
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     votes[0] += 1;
#                                                 }
#                                             }
#
#                                             else {
#                                                 votes[3] += 1;
#                                             }
#                                         }
#                                     }
#
#                                     else {
#                                         votes[0] += 1;
#                                     }
#                                 }
#
#                                 else {
#                                     votes[2] += 1;
#                                 }
#                             }
#
#                             else {
#                                 if (x[15] <= 8.979999542236328) {
#                                     if (x[9] <= 5.895000457763672) {
#                                         if (x[23] <= 5.069999694824219) {
#                                             if (x[2] <= 1.0550003051757812) {
#                                                 if (x[28] <= 1.4600000381469727) {
#                                                     if (x[8] <= 5.069999694824219) {
#                                                         votes[3] += 1;
#                                                     }
#
#                                                     else {
#                                                         votes[2] += 1;
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     votes[3] += 1;
#                                                 }
#                                             }
#
#                                             else {
#                                                 votes[1] += 1;
#                                             }
#                                         }
#
#                                         else {
#                                             votes[2] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         votes[3] += 1;
#                                     }
#                                 }
#
#                                 else {
#                                     votes[3] += 1;
#                                 }
#                             }
#                         }
#
#                         // tree #6
#                         if (x[28] <= 0.24000072479248047) {
#                             if (x[16] <= 8.979999542236328) {
#                                 if (x[25] <= -39.92500114440918) {
#                                     if (x[29] <= 1.0550003051757812) {
#                                         if (x[30] <= 0.804999828338623) {
#                                             if (x[4] <= 2.005000114440918) {
#                                                 if (x[14] <= 8.810001373291016) {
#                                                     if (x[1] <= 0.804999828338623) {
#                                                         if (x[13] <= 8.480003356933594) {
#                                                             if (x[8] <= 5.069999694824219) {
#                                                                 votes[1] += 1;
#                                                             }
#
#                                                             else {
#                                                                 votes[0] += 1;
#                                                             }
#                                                         }
#
#                                                         else {
#                                                             votes[1] += 1;
#                                                         }
#                                                     }
#
#                                                     else {
#                                                         if (x[7] <= 4.229999542236328) {
#                                                             if (x[6] <= 3.4200000762939453) {
#                                                                 votes[1] += 1;
#                                                             }
#
#                                                             else {
# ...
#                                             }
#                                         }
#
#                                         else {
#                                             if (x[29] <= 1.1100001335144043) {
#                                                 votes[0] += 1;
#                                             }
#
#                                             else {
#                                                 if (x[6] <= 5.325000762939453) {
#                                                     votes[0] += 1;
#                                                 }
#
#                                                 else {
#                                                     if (x[11] <= 7.394996643066406) {
#                                                         votes[3] += 1;
#                                                     }
#
#                                                     else {
#                                                         votes[1] += 1;
#                                                     }
#                                                 }
#                                             }
#                                         }
#                                     }
#
#                                     else {
#                                         votes[2] += 1;
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[17] <= 8.810001373291016) {
#                                         if (x[9] <= 5.895000457763672) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[2] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         votes[2] += 1;
#                                     }
#                                 }
#                             }
#
#                             else {
#                                 if (x[26] <= 2.6700000762939453) {
#                                     votes[2] += 1;
#                                 }
#
#                                 else {
#                                     votes[0] += 1;
#                                 }
#                             }
#                         }
#
#                         else {
#                             if (x[26] <= 2.6700000762939453) {
#                                 if (x[13] <= 8.480003356933594) {
#                                     if (x[15] <= 8.979999542236328) {
#                                         if (x[6] <= 3.4200000762939453) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             if (x[3] <= 1.4600000381469727) {
#                                                 votes[1] += 1;
#                                             }
#
#                                             else {
#                                                 if (x[19] <= 8.005001068115234) {
#                                                     votes[1] += 1;
#                                                 }
#
#                                                 else {
#                                                     votes[2] += 1;
#                                                 }
#                                             }
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[27] <= 2.005000114440918) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[0] <= 0.7199997901916504) {
#                                         votes[3] += 1;
#                                     }
#
#                                     else {
#                                         votes[1] += 1;
#                                     }
#                                 }
#                             }
#
#                             else {
#                                 votes[3] += 1;
#                             }
#                         }
#
#                         // tree #30
#                         if (x[23] <= 5.069999694824219) {
#                             if (x[22] <= -58.97999954223633) {
#                                 if (x[29] <= 1.0550003051757812) {
#                                     if (x[17] <= 8.810001373291016) {
#                                         if (x[2] <= -12.605000019073486) {
#                                             if (x[3] <= 1.4600000381469727) {
#                                                 if (x[25] <= 3.4200000762939453) {
#                                                     if (x[28] <= 1.4600000381469727) {
#                                                         if (x[6] <= 3.4200000762939453) {
#                                                             if (x[7] <= 4.229999542236328) {
#                                                                 votes[0] += 1;
#                                                             }
#
#                                                             else {
#                                                                 votes[1] += 1;
#                                                             }
#                                                         }
#
#                                                         else {
#                                                             votes[0] += 1;
#                                                         }
#                                                     }
#
#                                                     else {
#                                                         votes[3] += 1;
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     if (x[1] <= 0.804999828338623) {
#                                                         if (x[0] <= 0.7199997901916504) {
#                                                             votes[3] += 1;
#                                                         }
#
#                                                         else {
#                                                             votes[0] += 1;
#                                                         }
#                                                     }
#
#                                                     else {
#                                                         votes[3] += 1;
#                                                     }
#                                                 }
#                                             }
#
#                                             else {
#                                                 if (x[12] <= 8.005001068115234) {
#                                                     votes[2] += 1;
#                                                 }
#
#                                                 else {
#                                                     if (x[21] <= 6.68499755859375) {
#                                                         votes[1] += 1;
#                                                     }
#
#                                                     else {
#                                                         votes[2] += 1;
#                                                     }
#                                                 }
#                                             }
#                                         }
#
#                                         else {
#                                             if (x[9] <= 5.895000457763672) {
#                                                 if (x[27] <= 2.005000114440918) {
#                                                     if (x[15] <= 8.979999542236328) {
#                                                         if (x[7] <= 4.229999542236328) {
#                                                             if (x[26] <= 2.6700000762939453) {
#                                                                 votes[0] += 1;
#                                                             }
#
#                                                             else {
#                                                                 votes[1] += 1;
#                                                             }
#                                                         }
#
#                                                         else {
#                                                             votes[1] += 1;
#                                                         }
#                                                     }
#
#                                                     else {
#                                                         votes[3] += 1;
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     if (x[24] <= 4.229999542236328) {
#                                                         votes[1] += 1;
#                                                     }
#
#                                                     else {
#                                                         votes[3] += 1;
#                                                     }
#                                                 }
#                                             }
#
#                                             else {
#                                                 if (x[12] <= 8.005001068115234) {
#                                                     if (x[0] <= 0.7199997901916504) {
#                                                         votes[0] += 1;
#                                                     }
#
#                                                     else {
#                                                         votes[1] += 1;
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     votes[0] += 1;
#                                                 }
#                                             }
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[2] <= 1.0550003051757812) {
#                                             votes[2] += 1;
#                                         }
#
#                                         else {
#                                             votes[3] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[17] <= 8.810001373291016) {
#                                         if (x[3] <= 1.4600000381469727) {
#                                             if (x[27] <= 2.005000114440918) {
#                                                 votes[0] += 1;
#                                             }
#
#                                             else {
#                                                 if (x[4] <= 2.005000114440918) {
#                                                     votes[0] += 1;
#                                                 }
#
#                                                 else {
#                                                     votes[2] += 1;
#                                                 }
#                                             }
#                                         }
#
#                                         else {
#                                             if (x[30] <= 0.804999828338623) {
#                                                 votes[3] += 1;
#                                             }
#
#                                             else {
#                                                 votes[1] += 1;
#                                             }
#                                         }
#                                     }
#
#                                     else {
#                                         votes[2] += 1;
#                                     }
#                                 }
#                             }
#
#                             else {
#                                 if (x[0] <= 0.7199997901916504) {
#                                     votes[0] += 1;
#                                 }
#
#                                 else {
#                                     if (x[25] <= 4.944999694824219) {
#                                         if (x[11] <= 7.394996643066406) {
#                                             votes[3] += 1;
#                                         }
#
#                                         else {
#                                             votes[2] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         votes[2] += 1;
#                                     }
#                                 }
#                             }
#                         }
#
#                         else {
#                             if (x[19] <= 8.005001068115234) {
#                                 if (x[9] <= 5.895000457763672) {
#                                     if (x[17] <= 8.810001373291016) {
#                                         votes[2] += 1;
#                                     }
#
#                                     else {
#                                         votes[1] += 1;
#                                     }
#                                 }
#
#                                 else {
#                                     votes[3] += 1;
#                                 }
#                             }
#
#                             else {
#                                 votes[2] += 1;
#                             }
#                         }
#
#                         // return argmax of votes
#                         uint8_t classIdx = 0;
#                         float maxVotes = votes[0];
#
#                         for (uint8_t i = 1; i < 4; i++) {
#                             if (votes[i] > maxVotes) {
#                                 classIdx = i;
#                                 maxVotes = votes[i];
#                             }
#                         }
#
#                         return classIdx;
#                     }
#
#                     /**
#                     * Predict readable class name
#                     */
#                     const char* predictLabel(float *x) {
#                         return idxToLabel(predict(x));
#                     }
#
#                     /**
#                     * Convert class idx to readable name
#                     */
#                     const char* idxToLabel(uint8_t classIdx) {
#                         switch (classIdx) {
#                             case 0:
#                             return "Egypt";
#                             case 1:
#                             return "Japan";
#                             case 2:
#                             return "Nigeria";
#                             case 3:
#                             return "Tanzania";
#                             default:
#                             return "Houston we have a problem";
#                         }
#                     }
#
#                 protected:
#                 };
#             }
#         }
#     }
