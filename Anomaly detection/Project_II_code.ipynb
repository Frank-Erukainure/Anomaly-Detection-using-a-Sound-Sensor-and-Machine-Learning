# %%
import numpy as np
from os.path import basename
from glob import glob
from sklearn.svm import SVC
from micromlgen import port
from sklearn.model_selection import train_test_split

def load_features(folder):
    dataset = None
    classmap = {}
    for class_idx, filename in enumerate(glob('%s/*.csv' % folder)):
        class_name = basename(filename)[:-4]
        classmap[class_idx] = class_name
        samples = np.loadtxt(filename, dtype=float, delimiter=',')
        labels = np.ones((len(samples), 1)) * class_idx
        samples = np.hstack((samples, labels))
        dataset = samples if dataset is None else np.vstack((dataset, samples))
    return dataset, classmap

np.random.seed(0)
dataset, classmap = load_features('data3')
X, y = dataset[:, :-1], dataset[:, -1]
# this line is for testing your accuracy only: once you're satisfied with the results, set test_size to 1
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1)

clf = SVC(kernel='poly', degree=2, gamma=0.1, C=100)
clf.fit(X_train, y_train)

print('Accuracy', clf.score(X_test, y_test))
print('Exported classifier to plain C')
print(port(clf, classmap=classmap))
# Out:
# Accuracy 1.0
# Exported classifier to plain C
# #pragma once
# #include <cstdarg>
# namespace Eloquent {
#     namespace ML {
#         namespace Port {
#             class SVM {
#                 public:
#                     /**
#                     * Predict class for features vector
#                     */
#                     int predict(float *x) {
#                         float kernels[35] = { 0 };
#                         float decisions[1] = { 0 };
#                         int votes[2] = { 0 };
#                         kernels[0] = compute_kernel(x,   -90.37  , -90.37  , -89.55  , -90.37  , -90.37  , -90.37  , -90.37  , -90.37  , -90.37  , -90.37  , -90.37 );
#                         kernels[1] = compute_kernel(x,   -12.9  , -12.9  , -12.9  , -12.9  , -12.9  , -12.9  , -12.9  , -12.9  , -12.9  , -12.9  , -12.9 );
#                         kernels[2] = compute_kernel(x,   -17.87  , -17.87  , -17.87  , -17.87  , -17.87  , -17.87  , -17.87  , -17.87  , -17.87  , -17.87  , -17.87 );
#                         kernels[3] = compute_kernel(x,   -51.74  , -51.74  , -51.74  , -51.74  , -51.74  , -51.74  , -51.74  , -51.74  , -51.74  , -51.74  , -51.74 );
#                         kernels[4] = compute_kernel(x,   -72.08  , -72.08  , 81.26  , -72.08  , -72.08  , -72.08  , -72.08  , -72.08  , -72.08  , -72.08  , -72.08 );
#                         kernels[5] = compute_kernel(x,   -12.9  , -12.9  , -12.9  , -12.9  , -12.9  , -12.9  , -12.9  , -12.9  , -12.9  , -12.9  , -12.9 );
#                         kernels[6] = compute_kernel(x,   -109.74  , -109.74  , -109.74  , -109.74  , -109.74  , -109.74  , -109.74  , -109.74  , -109.74  , -109.74  , -109.74 );
#                         kernels[7] = compute_kernel(x,   -32.63  , -32.63  , -32.63  , -32.63  , -32.63  , -32.63  , -32.63  , -32.63  , -32.63  , -32.63  , -32.63 );
#                         kernels[8] = compute_kernel(x,   -109.74  , -109.74  , -109.74  , -109.74  , -109.74  , -109.74  , -109.74  , -109.74  , -109.74  , -109.74  , -109.74 );
#                         kernels[9] = compute_kernel(x,   -90.37  , -90.37  , -90.37  , -90.37  , -90.37  , -90.37  , -90.37  , -90.37  , -90.37  , -90.37  , -90.37 );
#                         kernels[10] = compute_kernel(x,   -61.96  , -61.96  , -61.96  , -61.96  , -61.96  , -61.96  , -61.96  , -61.96  , -61.96  , -61.96  , 70.41 );
#                         kernels[11] = compute_kernel(x,   53.71  , -103.64  , -103.64  , -103.64  , -103.64  , -103.64  , -103.64  , -103.64  , -103.64  , -103.64  , -103.64 );
#                         kernels[12] = compute_kernel(x,   -97.79  , -97.79  , -97.79  , -97.79  , -97.79  , -97.79  , -97.79  , -97.79  , -97.79  , -97.79  , -97.79 );
#                         kernels[13] = compute_kernel(x,   -51.74  , -51.74  , -51.74  , -51.74  , -51.74  , -51.74  , -51.74  , -51.74  , -51.74  , -51.74  , -51.74 );
#                         kernels[14] = compute_kernel(x,   -97.79  , -97.79  , -97.79  , -97.79  , -97.79  , -97.79  , -97.79  , -97.79  , -97.79  , -97.79  , -97.79 );
#                         kernels[15] = compute_kernel(x,   -17.87  , -17.87  , -17.87  , -17.87  , -17.87  , -17.87  , -17.87  , -17.87  , -17.87  , -17.87  , -17.87 );
#                         kernels[16] = compute_kernel(x,   9.92  , -8.8  , 9.84  , -8.8  , 9.84  , 9.84  , -8.56  , -8.64  , -8.8  , 9.92  , 10.0 );
#                         kernels[17] = compute_kernel(x,   -9.84  , -9.84  , -9.84  , -9.84  , -9.84  , -9.84  , -9.84  , -9.84  , -9.84  , -9.84  , -9.84 );
#                         kernels[18] = compute_kernel(x,   -12.9  , -12.9  , -12.9  , -12.9  , -12.9  , -12.9  , -12.78  , -12.9  , -12.9  , -12.9  , -12.9 );
#                         kernels[19] = compute_kernel(x,   -107.68  , -107.68  , -107.68  , -80.27  , -107.68  , -107.68  , -107.68  , -107.68  , -107.68  , -107.68  , 123.34 );
#                         kernels[20] = compute_kernel(x,   -24.54  , -24.54  , -24.54  , -24.54  , -24.54  , -24.54  , -24.54  , -24.54  , -24.54  , -24.54  , -24.54 );
#                         kernels[21] = compute_kernel(x,   -107.68  , -107.68  , -107.68  , -107.68  , -107.68  , -107.68  , -107.68  , -107.68  , -107.68  , -107.68  , -107.68 );
#                         kernels[22] = compute_kernel(x,   -97.79  , -97.79  , -97.79  , -97.79  , -97.79  , -97.79  , -97.79  , -97.79  , -97.79  , -97.79  , -97.79 );
#                         kernels[23] = compute_kernel(x,   -81.68  , -81.68  , -81.68  , -81.68  , -81.68  , -81.68  , -81.68  , -7.43  , -81.68  , -81.68  , -81.68 );
#                         kernels[24] = compute_kernel(x,   -17.71  , -17.87  , 20.63  , -17.87  , 20.63  , 20.47  , -17.87  , -17.87  , -17.87  , -17.87  , -17.87 );
#                         kernels[25] = compute_kernel(x,   -9.84  , -9.84  , -9.84  , -9.84  , -9.84  , -9.84  , -9.84  , -9.84  , -9.84  , 11.36  , -9.84 );
#                         kernels[26] = compute_kernel(x,   -1.68  , 10.08  , 10.08  , -8.8  , 10.08  , 10.08  , 10.16  , -7.6  , -8.64  , 10.08  , -8.16 );
#                         kernels[27] = compute_kernel(x,   -71.43  , -72.08  , -72.08  , -72.08  , -72.08  , -72.08  , -72.08  , -72.08  , -72.08  , -72.08  , -72.08 );
#                         kernels[28] = compute_kernel(x,   -41.83  , -41.83  , -41.83  , -41.83  , -41.83  , -41.83  , -41.83  , -41.83  , -41.83  , -41.83  , -41.83 );
#                         kernels[29] = compute_kernel(x,   -17.87  , -17.87  , -17.87  , -17.87  , -17.87  , -17.87  , -17.87  , -17.87  , -17.87  , -17.87  , -17.87 );
#                         kernels[30] = compute_kernel(x,   -61.96  , -61.96  , -61.96  , -61.96  , -61.96  , -61.96  , -61.96  , -61.96  , -61.96  , -61.96  , -61.96 );
#                         kernels[31] = compute_kernel(x,   -41.83  , -41.83  , -41.83  , -41.83  , -41.83  , -41.83  , -41.83  , -41.83  , -41.83  , -41.83  , -41.83 );
#                         kernels[32] = compute_kernel(x,   -103.64  , -103.64  , -103.64  , -103.64  , -103.64  , -103.64  , -103.64  , -103.64  , -103.64  , -103.64  , -103.64 );
#                         kernels[33] = compute_kernel(x,   -12.9  , -12.9  , -12.78  , -12.9  , -12.9  , -12.9  , -12.78  , -12.9  , -12.9  , -12.9  , -12.9 );
#                         kernels[34] = compute_kernel(x,   -61.96  , -61.96  , -61.96  , -61.96  , -61.4  , -61.96  , -61.96  , -61.96  , -61.96  , -61.4  , -61.96 );
#                         float decision = -50.563221155319;
#                         decision = decision - ( + kernels[0] * -1.697807172595  + kernels[1] * -100.0  + kernels[2] * -100.0  + kernels[3] * -100.0  + kernels[4] * -0.000526336005  + kernels[5] * -100.0  + kernels[6] * -100.0  + kernels[7] * -100.0  + kernels[8] * -100.0  + kernels[9] * -100.0  + kernels[10] * -0.022149601068  + kernels[11] * -0.012249175907  + kernels[12] * -7.53478425034  + kernels[13] * -100.0  + kernels[14] * -1.948986789422  + kernels[15] * -100.0  + kernels[16] * -0.035425947996 );
#                         decision = decision - ( + kernels[17] * 100.0  + kernels[18] * 6.069420170653  + kernels[19] * 0.008913061844  + kernels[20] * 100.0  + kernels[21] * 100.0  + kernels[22] * 100.0  + kernels[23] * 0.006137532342  + kernels[24] * 0.03238342525  + kernels[25] * 0.142333012513  + kernels[26] * 0.00438484554  + kernels[27] * 4.829986123487  + kernels[28] * 100.0  + kernels[29] * 100.0  + kernels[30] * 100.0  + kernels[31] * 100.0  + kernels[32] * 100.0  + kernels[33] * 100.0  + kernels[34] * 0.158371101676 );
#
#                         return decision > 0 ? 0 : 1;
#                     }
#
#                     /**
#                     * Predict readable class name
#                     */
#                     const char* predictLabel(float *x) {
#                         return idxToLabel(predict(x));
#                     }
#
#                     /**
#                     * Convert class idx to readable name
#                     */
#                     const char* idxToLabel(uint8_t classIdx) {
#                         switch (classIdx) {
#                             case 0:
#                             return "Abnormal fan condition";
#                             case 1:
#                             return "Normal fan condition";
#                             default:
#                             return "Houston we have a problem";
#                         }
#                     }
#
#                 protected:
#                     /**
#                     * Compute kernel between feature vector and support vector.
#                     * Kernel type: poly
#                     */
#                     float compute_kernel(float *x, ...) {
#                         va_list w;
#                         va_start(w, 11);
#                         float kernel = 0.0;
#
#                         for (uint16_t i = 0; i < 11; i++) {
#                             kernel += x[i] * va_arg(w, double);
#                         }
#
#                         return pow((0.1 * kernel) + 0.0, 2);
#                     }
#                 };
#             }
#         }
#     }

# %%
from sklearn.ensemble import RandomForestClassifier
from micromlgen import port
import numpy as np
from glob import glob
from os.path import basename
from sklearn.ensemble import RandomForestClassifier

def load_features(folder):
    dataset = None
    classmap = {}
    for class_idx, filename in enumerate(glob('%s/*.csv' % folder)):
        class_name = basename(filename)[:-4]
        classmap[class_idx] = class_name
        samples = np.loadtxt(filename, dtype=float, delimiter=',')
        labels = np.ones((len(samples), 1)) * class_idx
        samples = np.hstack((samples, labels))
        dataset = samples if dataset is None else np.vstack((dataset, samples))

    return dataset, classmap

np.random.seed(0)
dataset, classmap = load_features('data3')
X, y = dataset[:, :-1], dataset[:, -1]

classifier = RandomForestClassifier(n_estimators=30, max_depth=10).fit(X, y)
c_code = port(classifier, classmap=classmap)
print(c_code)
# Out:
# #pragma once
# #include <cstdarg>
# namespace Eloquent {
#     namespace ML {
#         namespace Port {
#             class RandomForest {
#                 public:
#                     /**
#                     * Predict class for features vector
#                     */
#                     int predict(float *x) {
#                         uint8_t votes[2] = { 0 };
#                         // tree #1
#                         if (x[20] <= -17.789999961853027) {
#                             if (x[2] <= -21.20500087738037) {
#                                 if (x[16] <= 9.510000228881836) {
#                                     if (x[14] <= -109.23999786376953) {
#                                         votes[0] += 1;
#                                     }
#
#                                     else {
#                                         if (x[1] <= -94.08000183105469) {
#                                             if (x[17] <= -105.65999984741211) {
#                                                 if (x[20] <= -107.18999862670898) {
#                                                     votes[1] += 1;
#                                                 }
#
#                                                 else {
#                                                     votes[0] += 1;
#                                                 }
#                                             }
#
#                                             else {
#                                                 votes[1] += 1;
#                                             }
#                                         }
#
#                                         else {
#                                             if (x[20] <= -61.68000030517578) {
#                                                 if (x[3] <= -76.88000106811523) {
#                                                     if (x[9] <= -81.31000137329102) {
#                                                         if (x[2] <= -100.27000045776367) {
#                                                             if (x[13] <= -105.65999984741211) {
#                                                                 votes[0] += 1;
#                                                             }
#
#                                                             else {
#                                                                 votes[1] += 1;
#                                                             }
#                                                         }
#
#                                                         else {
#                                                             votes[0] += 1;
#                                                         }
#                                                     }
#
#                                                     else {
#                                                         votes[1] += 1;
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     if (x[7] <= -61.68000030517578) {
#                                                         votes[0] += 1;
#                                                     }
#
#                                                     else {
#                                                         if (x[18] <= -67.02000045776367) {
#                                                             votes[0] += 1;
#                                                         }
#
#                                                         else {
#                                                             votes[1] += 1;
#                                                         }
#                                                     }
#                                                 }
#                                             }
#
#                                             else {
#                                                 if (x[18] <= 42.98500061035156) {
#                                                     if (x[16] <= -32.48500061035156) {
#                                                         if (x[11] <= -56.85000038146973) {
#                                                             votes[1] += 1;
#                                                         }
#
#                                                         else {
#                                                             if (x[17] <= 13.549999237060547) {
#                                                                 votes[1] += 1;
#                                                             }
#
#                                                             else {
#                                                                 votes[0] += 1;
#                                                             }
#                                                         }
#                                                     }
#
#                                                     else {
#                                                         if (x[8] <= -28.58500099182129) {
#                                                             votes[0] += 1;
#                                                         }
#
#                                                         else {
#                                                             votes[1] += 1;
#                                                         }
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     votes[0] += 1;
#                                                 }
#                                             }
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     votes[0] += 1;
#                                 }
#                             }
#
#                             else {
#                                 votes[0] += 1;
#                             }
#                         }
#
#                         else {
#                             if (x[21] <= -8.760000228881836) {
#                                 if (x[4] <= 10.759999752044678) {
#                                     votes[1] += 1;
#                                 }
#
#                                 else {
#                                     votes[0] += 1;
#                                 }
#                             }
#
#                             else {
#                                 votes[0] += 1;
#                             }
#                         }
#
#                         // tree #2
#                         if (x[7] <= -15.385000228881836) {
#                             if (x[0] <= -107.18999862670898) {
#                                 if (x[13] <= -109.23999786376953) {
#                                     if (x[11] <= 8.479999542236328) {
#                                         votes[1] += 1;
#                                     }
#
#                                     else {
#                                         votes[0] += 1;
#                                     }
#                                 }
#
#                                 else {
#                                     votes[0] += 1;
#                                 }
#                             }
#
#                             else {
#                                 if (x[11] <= -17.789999961853027) {
#                                     if (x[20] <= -42.185001373291016) {
#                                         if (x[9] <= -56.614999771118164) {
#                                             if (x[16] <= -61.68000030517578) {
#                                                 if (x[8] <= -71.81999969482422) {
#                                                     if (x[19] <= -81.31000137329102) {
#                                                         if (x[12] <= -86.0250015258789) {
#                                                             if (x[21] <= -105.16999816894531) {
#                                                                 votes[1] += 1;
#                                                             }
#
#                                                             else {
#                                                                 votes[0] += 1;
#                                                             }
#                                                         }
#
#                                                         else {
#                                                             votes[0] += 1;
#                                                         }
#                                                     }
#
#                                                     else {
#                                                         votes[1] += 1;
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     votes[1] += 1;
#                                                 }
#                                             }
#
#                                             else {
#                                                 votes[0] += 1;
#                                             }
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[0] <= -28.58500099182129) {
#                                             votes[1] += 1;
#                                         }
#
#                                         else {
#                                             if (x[1] <= -24.43000030517578) {
#                                                 votes[0] += 1;
#                                             }
#
#                                             else {
#                                                 votes[1] += 1;
#                                             }
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[18] <= -25.725001335144043) {
#                                         votes[1] += 1;
#                                     }
#
#                                     else {
#                                         votes[0] += 1;
#                                     }
#                                 }
#                             }
#                         }
#
#                         else {
#                             if (x[1] <= 0.679999828338623) {
#                                 if (x[18] <= -9.795000076293945) {
#                                     votes[0] += 1;
#                                 }
#
#                                 else {
#                                     if (x[0] <= -9.320000171661377) {
#                                         votes[1] += 1;
#                                     }
#
#                                     else {
#                                         votes[0] += 1;
#                                     }
#                                 }
#                             }
#
#                             else {
#                                 votes[1] += 1;
#                             }
#                         }
#
#                         // tree #3
#                         if (x[0] <= -12.839999675750732) {
#                             if (x[15] <= -15.139999389648438) {
#                                 if (x[1] <= -37.23000144958496) {
#                                     if (x[19] <= -61.68000030517578) {
#                                         if (x[11] <= -66.7400016784668) {
#                                             if (x[14] <= -81.31000137329102) {
#                                                 if (x[1] <= -94.08000183105469) {
#                                                     if (x[17] <= -105.65999984741211) {
#                                                         if (x[13] <= -108.70999908447266) {
#                                                             votes[1] += 1;
#                                                         }
#
#                                                         else {
#                                                             if (x[4] <= 8.319999694824219) {
#                                                                 votes[1] += 1;
#                                                             }
#
#                                                             else {
#                                                                 votes[0] += 1;
#                                                             }
#                                                         }
#                                                     }
#
#                                                     else {
#                                                         votes[1] += 1;
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     votes[0] += 1;
#                                                 }
#                                             }
#
#                                             else {
#                                                 votes[1] += 1;
#                                             }
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         votes[1] += 1;
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[3] <= -21.20500087738037) {
#                                         if (x[0] <= -93.63500213623047) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             if (x[5] <= -28.58500099182129) {
#                                                 votes[1] += 1;
#                                             }
#
#                                             else {
#                                                 if (x[10] <= -24.43000030517578) {
#                                                     votes[0] += 1;
#                                                 }
#
#                                                 else {
#                                                     votes[1] += 1;
#                                                 }
#                                             }
#                                         }
#                                     }
#
#                                     else {
#                                         votes[0] += 1;
#                                     }
#                                 }
#                             }
#
#                             else {
#                                 if (x[18] <= -21.20500087738037) {
#                                     if (x[15] <= 76.32499980926514) {
#                                         votes[0] += 1;
#                                     }
#
#                                     else {
#                                         votes[1] += 1;
#                                     }
#                                 }
#
#                                 else {
#                                     votes[1] += 1;
#                                 }
#                             }
#                         }
#
#                         else {
#                             if (x[9] <= -6.28000009059906) {
#                                 votes[0] += 1;
#                             }
#
#                             else {
#                                 votes[1] += 1;
#                             }
#                         }
#
#                         // tree #4
#                         if (x[15] <= -56.85000038146973) {
#                             if (x[9] <= -109.23999786376953) {
#                                 votes[0] += 1;
#                             }
#
#                             else {
#                                 if (x[16] <= -61.68000030517578) {
#                                     if (x[10] <= -97.34500122070312) {
#                                         votes[1] += 1;
#                                     }
#
#                                     else {
#                                         if (x[8] <= -76.88000106811523) {
#                                             if (x[14] <= -81.31000137329102) {
#                                                 if (x[13] <= -81.31000137329102) {
#                                                     if (x[18] <= -89.73500061035156) {
#                                                         votes[0] += 1;
#                                                     }
#
#                                                     else {
#                                                         votes[1] += 1;
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     votes[0] += 1;
#                                                 }
#                                             }
#
#                                             else {
#                                                 votes[1] += 1;
#                                             }
#                                         }
#
#                                         else {
#                                             votes[1] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     votes[0] += 1;
#                                 }
#                             }
#                         }
#
#                         else {
#                             if (x[18] <= -51.505001068115234) {
#                                 votes[0] += 1;
#                             }
#
#                             else {
#                                 if (x[5] <= -32.48500061035156) {
#                                     if (x[17] <= -46.55000114440918) {
#                                         votes[1] += 1;
#                                     }
#
#                                     else {
#                                         if (x[6] <= -41.64000129699707) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             if (x[9] <= -41.260000228881836) {
#                                                 votes[1] += 1;
#                                             }
#
#                                             else {
#                                                 if (x[13] <= -37.23000144958496) {
#                                                     votes[0] += 1;
#                                                 }
#
#                                                 else {
#                                                     votes[1] += 1;
#                                                 }
#                                             }
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[20] <= 5.914999485015869) {
#                                         if (x[1] <= -24.43000030517578) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             if (x[11] <= -21.20500087738037) {
#                                                 votes[1] += 1;
#                                             }
#
#                                             else {
#                                                 if (x[8] <= -15.385000228881836) {
#                                                     votes[0] += 1;
#                                                 }
#
#                                                 else {
#                                                     if (x[16] <= -12.839999675750732) {
#                                                         votes[1] += 1;
#                                                     }
#
#                                                     else {
#                                                         if (x[6] <= -8.760000228881836) {
#                                                             if (x[13] <= 1.2799997329711914) {
#                                                                 votes[0] += 1;
#                                                             }
#
#                                                             else {
#                                                                 votes[1] += 1;
#                                                             }
#                                                         }
#
#                                                         else {
#                                                             votes[1] += 1;
#                                                         }
#                                                     }
#                                                 }
#                                             }
#                                         }
#                                     }
#
#                                     else {
#                                         votes[1] += 1;
#                                     }
#                                 }
#                             }
#                         }
#
#                         // tree #5
#                         if (x[12] <= -46.78500175476074) {
#                             if (x[6] <= -56.85000038146973) {
#                                 if (x[10] <= -109.23999786376953) {
#                                     votes[1] += 1;
#                                 }
#
#                                 else {
#                                     if (x[1] <= -94.08000183105469) {
#                                         votes[1] += 1;
#                                     }
#
#                                     else {
#                                         if (x[19] <= -61.68000030517578) {
#                                             if (x[1] <= -86.0250015258789) {
#                                                 votes[0] += 1;
#                                             }
#
#                                             else {
#                                                 if (x[14] <= -94.08000183105469) {
#                                                     if (x[0] <= -106.68999862670898) {
#                                                         votes[0] += 1;
#                                                     }
#
#                                                     else {
#                                                         if (x[3] <= -100.71500015258789) {
#                                                             votes[1] += 1;
#                                                         }
#
#                                                         else {
#                                                             votes[0] += 1;
#                                                         }
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     if (x[10] <= -80.56999969482422) {
#                                                         if (x[21] <= -81.31000137329102) {
#                                                             votes[1] += 1;
#                                                         }
#
#                                                         else {
#                                                             votes[0] += 1;
#                                                         }
#                                                     }
#
#                                                     else {
#                                                         if (x[0] <= -67.02000045776367) {
#                                                             votes[1] += 1;
#                                                         }
#
#                                                         else {
#                                                             votes[0] += 1;
#                                                         }
#                                                     }
#                                                 }
#                                             }
#                                         }
#
#                                         else {
#                                             votes[1] += 1;
#                                         }
#                                     }
#                                 }
#                             }
#
#                             else {
#                                 votes[1] += 1;
#                             }
#                         }
#
#                         else {
#                             if (x[0] <= -28.58500099182129) {
#                                 if (x[16] <= -41.64000129699707) {
#                                     if (x[17] <= -66.10000228881836) {
#                                         votes[0] += 1;
#                                     }
#
#                                     else {
#                                         votes[1] += 1;
#                                     }
#                                 }
#
#                                 else {
#                                     votes[0] += 1;
#                                 }
#                             }
#
#                             else {
#                                 if (x[19] <= -9.795000076293945) {
#                                     if (x[5] <= -12.839999675750732) {
#                                         if (x[20] <= -17.789999961853027) {
#                                             if (x[2] <= -21.20500087738037) {
#                                                 votes[1] += 1;
#                                             }
#
#                                             else {
#                                                 votes[0] += 1;
#                                             }
#                                         }
#
#                                         else {
#                                             if (x[6] <= -15.304999351501465) {
#                                                 votes[1] += 1;
#                                             }
#
#                                             else {
#                                                 if (x[4] <= -12.839999675750732) {
#                                                     votes[0] += 1;
#                                                 }
#
#                                                 else {
#                                                     votes[1] += 1;
#                                                 }
#                                             }
#                                         }
#                                     }
#
#                                     else {
#                                         votes[0] += 1;
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[19] <= -9.275000095367432) {
#                                         votes[1] += 1;
#                                     }
#
#                                     else {
#                                         if (x[21] <= -8.760000228881836) {
#                                             votes[1] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#                                 }
#                             }
#                         }
#
#                         // tree #6
#                         if (x[1] <= 108.625) {
#                             if (x[6] <= -15.304999351501465) {
#                                 if (x[8] <= -56.85000038146973) {
#                                     if (x[8] <= -105.65999984741211) {
#                                         votes[1] += 1;
#                                     }
#
#                                     else {
#                                         if (x[0] <= 10.630001068115234) {
#                                             if (x[4] <= -97.00500106811523) {
#                                                 if (x[19] <= -103.16999816894531) {
#                                                     votes[0] += 1;
#                                                 }
#
#                                                 else {
#                                                     votes[1] += 1;
#                                                 }
#                                             }
#
#                                             else {
#                                                 if (x[19] <= -67.02000045776367) {
#                                                     votes[1] += 1;
#                                                 }
#
#                                                 else {
#                                                     if (x[19] <= -61.68000030517578) {
#                                                         votes[0] += 1;
#                                                     }
#
#                                                     else {
#                                                         votes[1] += 1;
#                                                     }
#                                                 }
#                                             }
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[21] <= -102.29000091552734) {
#                                         votes[0] += 1;
#                                     }
#
#                                     else {
#                                         if (x[16] <= 9.904999732971191) {
#                                             if (x[18] <= 42.98500061035156) {
#                                                 if (x[4] <= -21.09500026702881) {
#                                                     votes[1] += 1;
#                                                 }
#
#                                                 else {
#                                                     if (x[3] <= -17.464999198913574) {
#                                                         votes[1] += 1;
#                                                     }
#
#                                                     else {
#                                                         votes[0] += 1;
#                                                     }
#                                                 }
#                                             }
#
#                                             else {
#                                                 votes[0] += 1;
#                                             }
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#                                 }
#                             }
#
#                             else {
#                                 if (x[4] <= -12.839999675750732) {
#                                     votes[0] += 1;
#                                 }
#
#                                 else {
#                                     if (x[8] <= -8.760000228881836) {
#                                         if (x[13] <= -9.275000095367432) {
#                                             if (x[17] <= -11.369999885559082) {
#                                                 votes[1] += 1;
#                                             }
#
#                                             else {
#                                                 if (x[19] <= -9.795000076293945) {
#                                                     votes[0] += 1;
#                                                 }
#
#                                                 else {
#                                                     votes[1] += 1;
#                                                 }
#                                             }
#                                         }
#
#                                         else {
#                                             votes[1] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         votes[0] += 1;
#                                     }
#                                 }
#                             }
#                         }
#
#                         else {
#                             if (x[5] <= -103.16999816894531) {
#                                 votes[0] += 1;
#                             }
#
#                             else {
#                                 if (x[5] <= -100.24499893188477) {
#                                     votes[1] += 1;
#                                 }
#
#                                 else {
#                                     votes[0] += 1;
#                                 }
#                             }
#                         }
#
#                         // tree #7
#                         if (x[19] <= -9.795000076293945) {
#                             if (x[16] <= -15.385000228881836) {
#                                 if (x[6] <= -17.789999961853027) {
#                                     if (x[21] <= -28.58500099182129) {
#                                         if (x[15] <= -86.0250015258789) {
#                                             if (x[4] <= -100.71500015258789) {
#                                                 if (x[14] <= -109.23999786376953) {
#                                                     votes[0] += 1;
#                                                 }
#
#                                                 else {
#                                                     if (x[17] <= -103.16999816894531) {
#                                                         votes[1] += 1;
#                                                     }
#
#                                                     else {
#                                                         votes[0] += 1;
#                                                     }
#                                                 }
#                                             }
#
#                                             else {
#                                                 if (x[10] <= -97.34500122070312) {
#                                                     if (x[3] <= -102.73500061035156) {
#                                                         votes[0] += 1;
#                                                     }
#
#                                                     else {
#                                                         votes[1] += 1;
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     votes[0] += 1;
#                                                 }
#                                             }
#                                         }
#
#                                         else {
#                                             if (x[10] <= -32.48500061035156) {
#                                                 if (x[0] <= -81.31000137329102) {
#                                                     if (x[4] <= -98.6150016784668) {
#                                                         votes[1] += 1;
#                                                     }
#
#                                                     else {
#                                                         if (x[8] <= -86.0250015258789) {
#                                                             votes[0] += 1;
#                                                         }
#
#                                                         else {
#                                                             votes[1] += 1;
#                                                         }
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     if (x[6] <= -51.505001068115234) {
#                                                         votes[0] += 1;
#                                                     }
#
#                                                     else {
#                                                         if (x[17] <= -41.95000076293945) {
#                                                             votes[1] += 1;
#                                                         }
#
#                                                         else {
#                                                             votes[0] += 1;
#                                                         }
#                                                     }
#                                                 }
#                                             }
#
#                                             else {
#                                                 votes[1] += 1;
#                                             }
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[15] <= 1.625) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             votes[1] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     votes[1] += 1;
#                                 }
#                             }
#
#                             else {
#                                 if (x[2] <= 2.5250000953674316) {
#                                     votes[0] += 1;
#                                 }
#
#                                 else {
#                                     if (x[3] <= -22.765000343322754) {
#                                         votes[0] += 1;
#                                     }
#
#                                     else {
#                                         votes[1] += 1;
#                                     }
#                                 }
#                             }
#                         }
#
#                         else {
#                             votes[1] += 1;
#                         }
#
#                         // tree #8
#                         if (x[6] <= -8.760000228881836) {
#                             if (x[16] <= -9.320000171661377) {
#                                 if (x[14] <= -9.795000076293945) {
#                                     if (x[20] <= -11.309999942779541) {
#                                         if (x[0] <= -12.839999675750732) {
#                                             if (x[12] <= 12.390000343322754) {
#                                                 if (x[15] <= 33.00500011444092) {
#                                                     if (x[1] <= -89.73500061035156) {
#                                                         votes[1] += 1;
#                                                     }
#
#                                                     else {
#                                                         if (x[3] <= -15.059999465942383) {
#                                                             if (x[15] <= -20.960000038146973) {
#                                                                 votes[0] += 1;
#                                                             }
#
#                                                             else {
#                                                                 votes[0] += 1;
#                                                             }
#                                                         }
#
#                                                         else {
#                                                             votes[1] += 1;
#                                                         }
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     votes[1] += 1;
#                                                 }
#                                             }
#
#                                             else {
#                                                 if (x[10] <= -37.23000144958496) {
#                                                     if (x[18] <= -51.704999923706055) {
#                                                         votes[0] += 1;
#                                                     }
#
#                                                     else {
#                                                         votes[1] += 1;
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     votes[0] += 1;
#                                                 }
#                                             }
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         votes[1] += 1;
#                                     }
#                                 }
#
#                                 else {
#                                     votes[0] += 1;
#                                 }
#                             }
#
#                             else {
#                                 votes[0] += 1;
#                             }
#                         }
#
#                         else {
#                             if (x[14] <= -41.64000129699707) {
#                                 votes[1] += 1;
#                             }
#
#                             else {
#                                 if (x[20] <= -27.36500072479248) {
#                                     votes[0] += 1;
#                                 }
#
#                                 else {
#                                     votes[1] += 1;
#                                 }
#                             }
#                         }
#
#                         // tree #9
#                         if (x[0] <= 2.5250000953674316) {
#                             if (x[6] <= -94.08000183105469) {
#                                 if (x[10] <= -103.16999816894531) {
#                                     if (x[1] <= 123.18000030517578) {
#                                         if (x[3] <= -105.65999984741211) {
#                                             votes[1] += 1;
#                                         }
#
#                                         else {
#                                             if (x[21] <= -103.16999816894531) {
#                                                 votes[0] += 1;
#                                             }
#
#                                             else {
#                                                 votes[1] += 1;
#                                             }
#                                         }
#                                     }
#
#                                     else {
#                                         votes[0] += 1;
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[19] <= -97.34500122070312) {
#                                         votes[0] += 1;
#                                     }
#
#                                     else {
#                                         votes[1] += 1;
#                                     }
#                                 }
#                             }
#
#                             else {
#                                 if (x[21] <= -81.31000137329102) {
#                                     if (x[17] <= -86.0250015258789) {
#                                         if (x[5] <= -99.0250015258789) {
#                                             votes[1] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         votes[1] += 1;
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[11] <= -76.88000106811523) {
#                                         votes[0] += 1;
#                                     }
#
#                                     else {
#                                         if (x[4] <= 0.804999828338623) {
#                                             if (x[12] <= -46.78500175476074) {
#                                                 votes[1] += 1;
#                                             }
#
#                                             else {
#                                                 if (x[20] <= -17.789999961853027) {
#                                                     if (x[2] <= -21.20500087738037) {
#                                                         if (x[7] <= -37.040000915527344) {
#                                                             votes[0] += 1;
#                                                         }
#
#                                                         else {
#                                                             if (x[1] <= -24.43000030517578) {
#                                                                 votes[0] += 1;
#                                                             }
#
#                                                             else {
#                                                                 votes[1] += 1;
#                                                             }
#                                                         }
#                                                     }
#
#                                                     else {
#                                                         votes[0] += 1;
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     if (x[2] <= -11.309999942779541) {
#                                                         if (x[2] <= -12.839999675750732) {
#                                                             votes[1] += 1;
#                                                         }
#
# ...
#                                         if (x[5] <= -76.88000106811523) {
#                                             votes[0] += 1;
#                                         }
#
#                                         else {
#                                             if (x[1] <= -71.75500106811523) {
#                                                 votes[0] += 1;
#                                             }
#
#                                             else {
#                                                 if (x[14] <= -67.02000045776367) {
#                                                     votes[1] += 1;
#                                                 }
#
#                                                 else {
#                                                     votes[0] += 1;
#                                                 }
#                                             }
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     votes[1] += 1;
#                                 }
#                             }
#
#                             else {
#                                 if (x[15] <= -71.05500221252441) {
#                                     votes[1] += 1;
#                                 }
#
#                                 else {
#                                     if (x[9] <= -15.385000228881836) {
#                                         votes[0] += 1;
#                                     }
#
#                                     else {
#                                         if (x[16] <= -12.839999675750732) {
#                                             votes[1] += 1;
#                                         }
#
#                                         else {
#                                             votes[0] += 1;
#                                         }
#                                     }
#                                 }
#                             }
#                         }
#
#                         else {
#                             if (x[3] <= -37.23000144958496) {
#                                 if (x[0] <= -66.10000228881836) {
#                                     votes[1] += 1;
#                                 }
#
#                                 else {
#                                     votes[0] += 1;
#                                 }
#                             }
#
#                             else {
#                                 votes[1] += 1;
#                             }
#                         }
#
#                         // tree #29
#                         if (x[15] <= 13.125) {
#                             if (x[4] <= 0.804999828338623) {
#                                 if (x[6] <= -11.324999809265137) {
#                                     if (x[1] <= -21.09500026702881) {
#                                         if (x[2] <= -76.88000106811523) {
#                                             if (x[11] <= -106.68999862670898) {
#                                                 votes[1] += 1;
#                                             }
#
#                                             else {
#                                                 if (x[19] <= -97.34500122070312) {
#                                                     votes[0] += 1;
#                                                 }
#
#                                                 else {
#                                                     if (x[12] <= -89.73500061035156) {
#                                                         votes[1] += 1;
#                                                     }
#
#                                                     else {
#                                                         if (x[17] <= -81.31000137329102) {
#                                                             if (x[0] <= -81.31000137329102) {
#                                                                 votes[1] += 1;
#                                                             }
#
#                                                             else {
#                                                                 votes[0] += 1;
#                                                             }
#                                                         }
#
#                                                         else {
#                                                             votes[0] += 1;
#                                                         }
#                                                     }
#                                                 }
#                                             }
#                                         }
#
#                                         else {
#                                             if (x[4] <= -56.57000160217285) {
#                                                 votes[1] += 1;
#                                             }
#
#                                             else {
#                                                 if (x[18] <= 11.875) {
#                                                     if (x[10] <= -24.43000030517578) {
#                                                         if (x[18] <= -37.040000915527344) {
#                                                             if (x[8] <= -46.78500175476074) {
#                                                                 votes[0] += 1;
#                                                             }
#
#                                                             else {
#                                                                 votes[1] += 1;
#                                                             }
#                                                         }
#
#                                                         else {
#                                                             votes[0] += 1;
#                                                         }
#                                                     }
#
#                                                     else {
#                                                         votes[1] += 1;
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     votes[0] += 1;
#                                                 }
#                                             }
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[17] <= 45.719998359680176) {
#                                             if (x[6] <= -17.789999961853027) {
#                                                 votes[0] += 1;
#                                             }
#
#                                             else {
#                                                 if (x[21] <= -12.839999675750732) {
#                                                     votes[1] += 1;
#                                                 }
#
#                                                 else {
#                                                     votes[0] += 1;
#                                                 }
#                                             }
#                                         }
#
#                                         else {
#                                             votes[1] += 1;
#                                         }
#                                     }
#                                 }
#
#                                 else {
#                                     votes[1] += 1;
#                                 }
#                             }
#
#                             else {
#                                 if (x[21] <= -89.96000289916992) {
#                                     if (x[7] <= -102.73500061035156) {
#                                         votes[0] += 1;
#                                     }
#
#                                     else {
#                                         votes[1] += 1;
#                                     }
#                                 }
#
#                                 else {
#                                     votes[0] += 1;
#                                 }
#                             }
#                         }
#
#                         else {
#                             if (x[13] <= 35.160000801086426) {
#                                 votes[1] += 1;
#                             }
#
#                             else {
#                                 votes[0] += 1;
#                             }
#                         }
#
#                         // tree #30
#                         if (x[20] <= -109.23999786376953) {
#                             votes[1] += 1;
#                         }
#
#                         else {
#                             if (x[8] <= 33.00500011444092) {
#                                 if (x[17] <= -85.6150016784668) {
#                                     if (x[9] <= -100.71500015258789) {
#                                         if (x[15] <= 10.34000015258789) {
#                                             if (x[13] <= -103.16999816894531) {
#                                                 votes[0] += 1;
#                                             }
#
#                                             else {
#                                                 votes[1] += 1;
#                                             }
#                                         }
#
#                                         else {
#                                             votes[1] += 1;
#                                         }
#                                     }
#
#                                     else {
#                                         votes[0] += 1;
#                                     }
#                                 }
#
#                                 else {
#                                     if (x[2] <= -41.64000129699707) {
#                                         if (x[16] <= -61.68000030517578) {
#                                             if (x[15] <= 10.630001068115234) {
#                                                 if (x[16] <= -67.02000045776367) {
#                                                     votes[1] += 1;
#                                                 }
#
#                                                 else {
#                                                     if (x[19] <= -61.68000030517578) {
#                                                         votes[0] += 1;
#                                                     }
#
#                                                     else {
#                                                         votes[1] += 1;
#                                                     }
#                                                 }
#                                             }
#
#                                             else {
#                                                 votes[0] += 1;
#                                             }
#                                         }
#
#                                         else {
#                                             if (x[3] <= -46.78500175476074) {
#                                                 votes[0] += 1;
#                                             }
#
#                                             else {
#                                                 if (x[4] <= -41.64000129699707) {
#                                                     if (x[18] <= -46.78500175476074) {
#                                                         votes[1] += 1;
#                                                     }
#
#                                                     else {
#                                                         if (x[9] <= -41.260000228881836) {
#                                                             votes[1] += 1;
#                                                         }
#
#                                                         else {
#                                                             votes[0] += 1;
#                                                         }
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     votes[1] += 1;
#                                                 }
#                                             }
#                                         }
#                                     }
#
#                                     else {
#                                         if (x[0] <= -13.774999618530273) {
#                                             if (x[15] <= -21.20500087738037) {
#                                                 if (x[2] <= 1.8949995040893555) {
#                                                     if (x[3] <= -37.23000144958496) {
#                                                         votes[0] += 1;
#                                                     }
#
#                                                     else {
#                                                         votes[1] += 1;
#                                                     }
#                                                 }
#
#                                                 else {
#                                                     votes[0] += 1;
#                                                 }
#                                             }
#
#                                             else {
#                                                 votes[0] += 1;
#                                             }
#                                         }
#
#                                         else {
#                                             if (x[6] <= -9.795000076293945) {
#                                                 if (x[9] <= -6.800000071525574) {
#                                                     votes[0] += 1;
#                                                 }
#
#                                                 else {
#                                                     votes[1] += 1;
#                                                 }
#                                             }
#
#                                             else {
#                                                 votes[1] += 1;
#                                             }
#                                         }
#                                     }
#                                 }
#                             }
#
#                             else {
#                                 votes[1] += 1;
#                             }
#                         }
#
#                         // return argmax of votes
#                         uint8_t classIdx = 0;
#                         float maxVotes = votes[0];
#
#                         for (uint8_t i = 1; i < 2; i++) {
#                             if (votes[i] > maxVotes) {
#                                 classIdx = i;
#                                 maxVotes = votes[i];
#                             }
#                         }
#
#                         return classIdx;
#                     }
#
#                     /**
#                     * Predict readable class name
#                     */
#                     const char* predictLabel(float *x) {
#                         return idxToLabel(predict(x));
#                     }
#
#                     /**
#                     * Convert class idx to readable name
#                     */
#                     const char* idxToLabel(uint8_t classIdx) {
#                         switch (classIdx) {
#                             case 0:
#                             return "Blender";
#                             case 1:
#                             return "Extractor";
#                             default:
#                             return "Houston we have a problem";
#                         }
#                     }
#
#                 protected:
#                 };
#             }
#         }
#     }
